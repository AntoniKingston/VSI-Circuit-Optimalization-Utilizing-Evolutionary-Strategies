# %% [markdown]
# # Szybkie testowanie

# %%
from algorithms import compute_value

# %%
compute_value([1,2,3,4,6,7], 4, "client.py")
# Out:
# 3.8321039391431038

# %%
import numpy as np

# %%
type(list(np.random.normal(0, 1, 10)))
# Out:
# list
